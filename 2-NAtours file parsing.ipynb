# %%
import json
import re
import os
import time
from dicttoxml import dicttoxml
import xml.dom.minidom

# Step 1: Load the HTML file from disk
# html_file_path = r'C:\Users\mjsteenberg\Documents\VoiceMap\Viator\scraped_pages\Gjirokaster_d50367-ttd_sortType_rating.html'  # Replace with your actual HTML file path
html_file_path = os.path.join(os.getcwd(), 'scraped_pages', 'NAtours', 'Acapulco_d629-ttd_sortType_rating.html')


with open(html_file_path, 'r', encoding='utf-8') as file:
    html_content = file.read()

# Step 2: Extract JSON data between "productList" and "productFilters"
pattern = r'"productList"\s*:\s*(\{.*?\})\s*,\s*"productFilters"'
match = re.search(pattern, html_content, re.DOTALL)

if not match:
    raise ValueError('Could not find JSON data between "productList" and "productFilters".')

product_list_json_str = match.group(1)

# Step 3: Ensure the extracted JSON is valid
product_list_json_str = '{ "productList": ' + product_list_json_str + ' }'
product_list_json_str = product_list_json_str.replace('\\u002F', '/')

# Step 4: Parse the JSON to get the "productList" data
try:
    product_list_data = json.loads(product_list_json_str)
except json.JSONDecodeError as e:
    print("JSON decoding failed:", e)
    raise

product_list = product_list_data['productList']

# Optional: Print or process the extracted data
total_count = product_list.get('totalCount')
pages = product_list.get('pages')
current_page = product_list.get('currentPage')
products = product_list.get('products')

print(f"Total Count: {total_count}")
print(f"Pages: {pages}")
print(f"Current Page: {current_page}")
print(f"Number of Products: {len(products)}")

# Step 5: Extract the first part of the filename until the first underscore
# Get the base filename without the directory path
base_filename = os.path.basename(html_file_path)

# Remove the file extension
filename_without_extension = os.path.splitext(base_filename)[0]

# Extract the part before the first underscore
location_name = filename_without_extension.split('_')[0]

# Step 6: Add the extracted location name as a value under a tag called "Destination"
product_list['Destination'] = location_name

# Step 7: Add the filename and file creation datetime to the product list data

# Get the file creation time
creation_time = os.path.getctime(html_file_path)
# Convert it to a readable format
creation_datetime = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(creation_time))

# Add the filename and creation datetime to the product list
product_list['FileName'] = base_filename
product_list['FileCreationDateTime'] = creation_datetime

# Step 8: Convert the entire "productList" to XML using dicttoxml
xml_bytes = dicttoxml(product_list, custom_root='ProductList', attr_type=False)
xml_str = xml_bytes.decode('utf-8')

# Pretty-print the XML
dom = xml.dom.minidom.parseString(xml_str)
pretty_xml_str = dom.toprettyxml()

# Step 9: Save the XML data to a file
xml_file_path = 'product_list.xml'  # Replace with your desired output XML file path

with open(xml_file_path, 'w', encoding='utf-8') as file:
    file.write(pretty_xml_str)

print(f"XML data has been saved to '{xml_file_path}'")
# Out:
# Total Count: 131
# Pages: 6
# Current Page: 1
# Number of Products: 24
# XML data has been saved to 'product_list.xml'

# %%
import json
import re
import os
import time
from dicttoxml import dicttoxml
import xml.dom.minidom

# Print current working directory
print(f"Current working directory: {os.getcwd()}")

# Define the XML directory path
xml_output_directory = os.path.join(os.getcwd(), 'scraped_pages', 'XML')

# Print the path we're trying to create
print(f"Attempting to create directory at: {xml_output_directory}")

# Directory containing HTML files
html_directory = os.path.join(os.getcwd(), 'scraped_pages', 'NAtours')

# Directory to save XML files - update to correct path
xml_output_directory = os.path.join(os.getcwd(), 'scraped_pages', 'XML')

# Debug prints to verify paths
print(f"HTML directory: {html_directory}")
print(f"XML output directory: {xml_output_directory}")

# Ensure output directory exists
os.makedirs(xml_output_directory, exist_ok=True)

# Rest of your code remains the same...
# Create XML directory and its parents if they don't exist
os.makedirs(xml_output_directory, exist_ok=True)

# Loop through all HTML files in the directory
for filename in os.listdir(html_directory):
    if filename.endswith('.html'):
        html_file_path = os.path.join(html_directory, filename)
        
        # Load the HTML file
        with open(html_file_path, 'r', encoding='utf-8') as file:
            html_content = file.read()
        
        # Extract JSON data between "productList" and "productFilters"
        pattern = r'"productList"\s*:\s*(\{.*?\})\s*,\s*"productFilters"'
        match = re.search(pattern, html_content, re.DOTALL)
        
        if not match:
            print(f'Could not find JSON data in file: {filename}')
            continue  # Skip to the next file
        
        product_list_json_str = match.group(1)
        
        # Ensure the extracted JSON is valid
        product_list_json_str = '{ "productList": ' + product_list_json_str + ' }'
        product_list_json_str = product_list_json_str.replace('\\u002F', '/')
        
        # Parse the JSON to get the "productList" data
        try:
            product_list_data = json.loads(product_list_json_str)
        except json.JSONDecodeError as e:
            print(f"JSON decoding failed for file {filename}: {e}")
            continue  # Skip to the next file
        
        product_list = product_list_data['productList']
        
        # Extract metadata from filename and file properties
        # Get the base filename without the directory path
        base_filename = os.path.basename(html_file_path)
        
        # Remove the file extension
        filename_without_extension = os.path.splitext(base_filename)[0]
        
        # Extract the part before the first underscore
        location_name = filename_without_extension.split('_')[0]
        
        # Get the file creation time
        creation_time = os.path.getctime(html_file_path)
        # Convert it to a readable format
        creation_datetime = time.strftime('%Y-%m-%d %H:%M:%S', time.localtime(creation_time))
        
        # Add the extracted metadata to the product list
        product_list['Destination'] = location_name
        product_list['FileName'] = base_filename
        product_list['FileCreationDateTime'] = creation_datetime
        
        # Convert the entire "productList" to XML
        xml_bytes = dicttoxml(product_list, custom_root='ProductList', attr_type=False)
        xml_str = xml_bytes.decode('utf-8')
        
        # Pretty-print the XML
        dom = xml.dom.minidom.parseString(xml_str)
        pretty_xml_str = dom.toprettyxml()
        
        # Save the XML data to a file
        xml_filename = filename_without_extension + '.xml'
        xml_file_path = os.path.join(xml_output_directory, xml_filename)
        
        with open(xml_file_path, 'w', encoding='utf-8') as file:
            file.write(pretty_xml_str)
        
        print(f"Processed and saved XML for file '{filename}' as '{xml_filename}'")
# Out:
# Current working directory: /Users/mjsteenberg/Desktop/Desktop - MJ’s MacBook Air - 1/VM/viator-scraper
# Attempting to create directory at: /Users/mjsteenberg/Desktop/Desktop - MJ’s MacBook Air - 1/VM/viator-scraper/scraped_pages/XML
# HTML directory: /Users/mjsteenberg/Desktop/Desktop - MJ’s MacBook Air - 1/VM/viator-scraper/scraped_pages/NAtours
# XML output directory: /Users/mjsteenberg/Desktop/Desktop - MJ’s MacBook Air - 1/VM/viator-scraper/scraped_pages/XML
# Processed and saved XML for file 'Newark_d22848-ttd_sortType_rating.html' as 'Newark_d22848-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Oahu_d672-ttd_sortType_rating.html' as 'Oahu_d672-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Gatlinburg_d24151-ttd_sortType_rating.html' as 'Gatlinburg_d24151-ttd_sortType_rating.xml'
# Processed and saved XML for file '
ttd_sortType_rating.xml'
# Processed and saved XML for file 'Florida_d276-ttd_sortType_rating.html' as 'Florida_d276-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Nantucket_d50773-ttd_sortType_rating.html' as 'Nantucket_d50773-ttd_sortType_rating.xml'
# Processed and saved XML for file 'West-Yellowstone_d50636-ttd_sortType_rating.html' as 'West-Yellowstone_d50636-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Flagstaff_d21450-ttd_sortType_rating.html' as 'Flagstaff_d21450-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Syracuse_d23062-ttd_sortType_rating.html' as 'Syracuse_d23062-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Astoria_d4370-ttd_sortType_rating.html' as 'Astoria_d4370-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Iowa_d22217-ttd_sortType_rating.html' as 'Iowa_d22217-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Amarillo_d29045-ttd_sortType_rating.html' as 'Amarillo_d29045-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Las-Vegas_d684-ttd_sortType_rating.html' as 'Las-Vegas_d684-ttd_sortType_rating.xml'
# Processed and saved XML for file 'New-Haven_d23481-ttd_sortType_rating.html' as 'New-Haven_d23481-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Vancouver_d616-ttd_sortType_rating.html' as 'Vancouver_d616-ttd_sortType_rating.xml'
# Processed and saved XML for file 'New-England_d60433-ttd_sortType_rating.html' as 'New-England_d60433-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Wilmington_d33417-ttd_sortType_rating.html' as 'Wilmington_d33417-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Ogden_d50800-ttd_sortType_rating.html' as 'Ogden_d50800-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Key-West_d661-ttd_sortType_rating.html' as 'Key-West_d661-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Stockton_d22359-ttd_sortType_rating.html' as 'Stockton_d22359-ttd_sortType_rating.xml'
# Processed and saved XML for file 'South-Carolina_d294-ttd_sortType_rating.html' as 'South-Carolina_d294-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Long-Beach_d5409-ttd_sortType_rating.html' as 'Long-Beach_d5409-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Mississippi_d22220-ttd_sortType_rating.html' as 'Mississippi_d22220-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Kalamazoo_d50775-ttd_sortType_rating.html' as 'Kalamazoo_d50775-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Santa-Monica_d32539-ttd_sortType_rating.html' as 'Santa-Monica_d32539-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Missouri_d5234-ttd_sortType_rating.html' as 'Missouri_d5234-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Lake-Tahoe_d816-ttd_sortType_rating.html' as 'Lake-Tahoe_d816-ttd_sortType_rating.xml'
# Processed and saved XML for file 'London_d50648-ttd_sortType_rating.html' as 'London_d50648-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Nebraska_d22222-ttd_sortType_rating.html' as 'Nebraska_d22222-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Kejimkujik-National-Park_d50645-ttd_sortType_rating.html' as 'Kejimkujik-National-Park_d50645-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Guerrero_d24408-ttd_sortType_rating.html' as 'Guerrero_d24408-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Jackson-Hole_d5261-ttd_sortType_rating.html' as 'Jackson-Hole_d5261-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Lahaina_d51005-ttd_sortType_rating.html' as 'Lahaina_d51005-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Oakland_d22040-ttd_sortType_rating.html' as 'Oakland_d22040-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Jacksonville_d4373-ttd_sortType_rating.html' as 'Jacksonville_d4373-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Tuxtla-Gutierrez_d23478-ttd_sortType_rating.html' as 'Tuxtla-Gutierrez_d23478-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Tybee-Island_d50765-ttd_sortType_rating.html' as 'Tybee-Island_d50765-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Puerto-Escondido_d23875-ttd_sortType_rating.html' as 'Puerto-Escondido_d23875-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Louisiana_d22168-ttd_sortType_rating.html' as 'Louisiana_d22168-ttd_sortType_rating.xml'
# Processed and saved XML for file 'North-Carolina_d5283-ttd_sortType_rating.html' as 'North-Carolina_d5283-ttd_sortType_rating.xml'
# Processed and saved XML for file '
ttd_sortType_rating.xml'
# Processed and saved XML for file 'Little-Rock_d50756-ttd_sortType_rating.html' as 'Little-Rock_d50756-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Bowling-Green_d50733-ttd_sortType_rating.html' as 'Bowling-Green_d50733-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Destin_d25549-ttd_sortType_rating.html' as 'Destin_d25549-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Tampa_d666-ttd_sortType_rating.html' as 'Tampa_d666-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Tulsa_d50783-ttd_sortType_rating.html' as 'Tulsa_d50783-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Page_d23393-ttd_sortType_rating.html' as 'Page_d23393-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Revelstoke_d50914-ttd_sortType_rating.html' as 'Revelstoke_d50914-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Brooklyn_d22371-ttd_sortType_rating.html' as 'Brooklyn_d22371-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Banff_d611-ttd_sortType_rating.html' as 'Banff_d611-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Hilton-Head-Island_d31480-ttd_sortType_rating.html' as 'Hilton-Head-Island_d31480-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Mount-Pleasant_d50740-ttd_sortType_rating.html' as 'Mount-Pleasant_d50740-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Capitol-Reef-National-Park_d52058-ttd_sortType_rating.html' as 'Capitol-Reef-National-Park_d52058-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Sequoia-and-Kings-Canyon-National-Park_d50760-ttd_sortType_rating.html' as 'Sequoia-and-Kings-Canyon-National-Park_d50760-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Bar-Harbor_d4371-ttd_sortType_rating.html' as 'Bar-Harbor_d4371-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Fraser-Valley_d29722-ttd_sortType_rating.html' as 'Fraser-Valley_d29722-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Quebec_d264-ttd_sortType_rating.html' as 'Quebec_d264-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Mobile_d4377-ttd_sortType_rating.html' as 'Mobile_d4377-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Kansas_d22218-ttd_sortType_rating.html' as 'Kansas_d22218-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Mendocino_d50761-ttd_sortType_rating.html' as 'Mendocino_d50761-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Cambridge_d22877-ttd_sortType_rating.html' as 'Cambridge_d22877-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Savannah_d5166-ttd_sortType_rating.html' as 'Savannah_d5166-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Baltimore_d4375-ttd_sortType_rating.html' as 'Baltimore_d4375-ttd_sortType_rating.xml'
# Processed and saved XML for file 'New-London_d23486-ttd_sortType_rating.html' as 'New-London_d23486-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Gardiner_d50734-ttd_sortType_rating.html' as 'Gardiner_d50734-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Honolulu_d59070-ttd_sortType_rating.html' as 'Honolulu_d59070-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Philadelphia_d906-ttd_sortType_rating.html' as 'Philadelphia_d906-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Panama-City-Beach_d22828-ttd_sortType_rating.html' as 'Panama-City-Beach_d22828-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Myrtle-Beach_d5217-ttd_sortType_rating.html' as 'Myrtle-Beach_d5217-ttd_sortType_rating.xml'
# Processed and saved XML for file 'New-Hampshire_d22223-ttd_sortType_rating.html' as 'New-Hampshire_d22223-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Cozumel_d632-ttd_sortType_rating.html' as 'Cozumel_d632-ttd_sortType_rating.xml'
# Processed and saved XML for file 'St-George_d23945-ttd_sortType_rating.html' as 'St-George_d23945-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Canon-City_d22360-ttd_sortType_rating.html' as 'Canon-City_d22360-ttd_sortType_rating.xml'
# Processed and saved XML for file 'South-Padre-Island_d22446-ttd_sortType_rating.html' as 'South-Padre-Island_d22446-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Chiapas_d5506-ttd_sortType_rating.html' as 'Chiapas_d5506-ttd_sortType_rating.xml'
# Processed and saved XML for file 'Villahermosa_d50611-ttd_sortType_rating.html' as 'Villahermosa_d50611-ttd_sortType_rating.xml'
